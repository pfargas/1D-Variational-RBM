# %%
include("utils.jl")
# Out:
# energy

# %%
λ = 0.5f0 - 1.f0im
b = 0.f0 +0.f0im
c = [(0.f0 +0.f0im), 0.f0 +0.f0im]
w = [(0.f0 +0.f0im), 0.f0 +0.f0im]

Ψ_G(1.f0,λ,b,c,w)
# Out:
# 1.3108397f0 + 2.0415118f0im

# %%
# Test Simulated_Annealing

f(x::Vector) = (x[1]+2*x[2])^2
x0 = [0.5,1]
T0 = 10
N = 100
α = 0.9
x,chain = Simulated_Annealing(f, x0, T0, N, α)

using PyPlot
clf()
plot(chain[:,1], label="x1")
plot(chain[:,2], label="x2")
xlabel("Iteration")
ylabel("Objective function value")
title("Simulated Annealing")
legend()
display(gcf())
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
clf()
plot(randn(100))
display(gcf())
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
